# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs, make_circles
from sklearn.metrics import accuracy_score

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=0)
X = X.T
y = y.reshape((1, y.shape[0]))

print('dimensions de X:', X.shape)
print('dimensions de y:', y.shape)

plt.scatter(X[0, :], X[1, :], c=y, cmap='summer')
plt.show()
# Out:
# dimensions de X: (2, 100)
# dimensions de y: (1, 100)

# %%
def initialisation(layers):
    params = []
    for i in range(1, len(layers)):
        params.append({
            "W": np.random.randn(layers[i], layers[i-1]),
            "b": np.random.randn(layers[i], 1),
        })
    return params

# %%
params = initialisation([X.shape[0], 16, 16, y.shape[0]])
for i, p in enumerate(params, start=1):
    print(f"Param {i}")
    print(f"  -> Shape of W: {p['W'].shape}")
    print(f"  -> Shape of b: {p['b'].shape}")
# Out:
# Param 1
#   -> Shape of W: (16, 2)
#   -> Shape of b: (16, 1)
# Param 2
#   -> Shape of W: (16, 16)
#   -> Shape of b: (16, 1)
# Param 3
#   -> Shape of W: (1, 16)
#   -> Shape of b: (1, 1)

# %%
def forward_propagation(X, params):
    Z = params[0]["W"].dot(X) + params[0]["b"]
    activations = [1 / (1 + np.exp(-Z))]
    for p in params[1:]:
        Z = p["W"].dot(activations[-1]) + p["b"]
        activations.append(1 / (1 + np.exp(-Z)))
    return activations

# %%
activations = forward_propagation(X, params)
print(f"X shape: {X.shape}")
for i, A in enumerate(activations, start=1):
    print(f"A{i} shape: {A.shape}")
# Out:
# X shape: (2, 100)
# A1 shape: (16, 100)
# A2 shape: (16, 100)
# A3 shape: (1, 100)

# %%
def log_loss(A, y):
    return (1 / len(y)) * np.sum(-y * np.log(A) - (1 - y) * np.log(1 - A))

# %%
def back_propagation(X, y, activations, params):
    Ws = [p["W"] for p in params]

    m = y.shape[1]

    dZ = activations[-1] - y
    gradients = [{
        "dW": 1 / m * dZ.dot(activations[-2].T),
        "db": 1 / m * np.sum(dZ, axis=1, keepdims=True) 
    }]

    for i in range(len(activations) - 2, 0, -1):
        dZ = np.dot(Ws[i+1].T, dZ) * activations[i] * (1 - activations[i])
        gradients.append({
            "dW": 1 / m * dZ.dot(activations[i].T),
            "db": 1 / m * np.sum(dZ, axis=1, keepdims=True)
        })

    dZ = np.dot(Ws[1].T, dZ) * activations[0] * (1 - activations[0])
    gradients.append({
        "dW": 1 / m * dZ.dot(X.T),
        "db": 1 / m * np.sum(dZ, axis=1, keepdims=True)
    })

    gradients.reverse()
    return gradients

# %%
gradients = back_propagation(X, y, activations, params)
for i, g in enumerate(gradients, start=1):
    print(f"dW{i} shape: {g['dW'].shape}")
    print(f"db{i} shape: {g['db'].shape}")
# Out:
# dW1 shape: (16, 2)
# db1 shape: (16, 1)
# dW2 shape: (16, 16)
# db2 shape: (16, 1)
# dW3 shape: (1, 16)
# db3 shape: (1, 1)

# %%
def update(gradients, params, learning_rate):
    # W = W - learning_rate * dW
    # b = b - learning_rate * db
    # return (W, b)

    new_params = []

    for g, p in zip(gradients, params):
        new_params.append(
            {
                "W": p["W"] - learning_rate * g["dW"],
                "b": p["b"] - learning_rate * g["db"],
            }
        )

    return new_params

# %%
new_params = update(gradients, params, 0.1)
for i, p in enumerate(new_params, start=1):
    print(f"Param {i}")
    print(f"  -> Shape of W: {p['W'].shape}")
    print(f"  -> Shape of b: {p['b'].shape}")
# Out:
# Param 1
#   -> Shape of W: (16, 2)
#   -> Shape of b: (16, 1)
# Param 2
#   -> Shape of W: (16, 16)
#   -> Shape of b: (16, 1)
# Param 3
#   -> Shape of W: (1, 16)
#   -> Shape of b: (1, 1)

# %%
def predict(X, params):
    activations = forward_propagation(X, params)
    return activations[-1] >= 0.5

# %%
def predict_proba(X, params):
    return forward_propagation(X, params)[-1]

# %%
def neural_network(X, y, hidden_layers=[16, 16, 16], learning_rate=0.1, n_iter=1000):
    params = initialisation([X.shape[0], *hidden_layers, y.shape[0]])

    train_loss = []
    train_acc = []

    for i in range(n_iter):
        activations = forward_propagation(X, params)
        gradients = back_propagation(X, y, activations, params)
        params = update(gradients, params, learning_rate)
        
        train_loss.append(log_loss(activations[-1], y))
        y_pred = predict(X, params)
        train_acc.append(accuracy_score(y.flatten(), y_pred.flatten()))
    
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='train loss')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='train acc')
    plt.legend()
    plt.show()
    print(f"Final loss: {train_loss[-1]}")
    print(f"Final accuracy: {train_acc[-1]}")

    return params

# %%
params = neural_network(X, y)
# Out:
# Final loss: 14.985082248542126
# Final accuracy: 0.94

# %%
params
# Out:
# [{'W': array([[ 0.69105106, -0.88168964],
#          [ 0.12466969, -1.06212698],
#          [ 0.48684681, -0.78948521],
#          [-0.43081759,  0.83277031],
#          [-0.30520728,  0.66623433],
#          [-2.33863324, -1.86134604],
#          [ 0.82570238, -1.63885903],
#          [ 1.55361799,  1.74446963],
#          [ 2.03905874,  1.49678538],
#          [-0.73961648,  0.95957166],
#          [-0.55825453,  0.4938637 ],
#          [ 0.1745802 ,  0.60683768],
#          [ 0.8198144 ,  0.25127491],
#          [-0.02415097,  0.35100425],
#          [ 0.75871638,  1.03304427],
#          [-0.27557659, -2.00085619]]),
#   'b': array([[ 1.11593386],
#          [ 2.26082991],
#          [ 0.52017125],
#          [-0.55417833],
#          [ 0.00766185],
#          [-0.0373464 ],
#          [-0.10858621],
#          [-0.85599693],
#          [-0.5482327 ],
#          [-1.03464162],
#          [-0.80778907],
#          [-1.48163229],
#          [-1.4034946 ],
#          [ 1.42340299],
#          [ 0.44222922],
#          [-0.28746971]])},
#  {'W': array([[ 1.64489605e-01,  4.02366728e-01, -6.72240821e-01,
#            1.64717174e-01,  2.30410470e-01,  1.20569903e+00,
#           -2.52939266e-01, -1.90146964e+00,  1.65458486e+00,
#            1.79309722e-01,  4.12160503e-01,  1.32439460e-01,
#           -1.56238433e+00,  1.02531309e+00, -1.22226806e+00,
#           -1.67526788e+00],
#          [-8.80127797e-01, -2.30329724e+00, -1.41274476e+00,
#            2.71631352e-02, -9.68401862e-01, -4.06470949e-01,
#            7.55923644e-02, -6.16554018e-01, -1.64980312e+00,
#            6.78950373e-01, -3.46475076e-01, -4.93688446e-01,
#           -1.17191163e+00,  7.86532882e-01, -8.62950245e-02,
#           -1.66242845e-01,  1.27183797e-01,  3.16339999e-01,
#            1.80892324e-01],
#          [-5.30491492e-01,  1.44870280e+00, -8.59895071e-01,
#            1.52119855e-01,  1.02103282e-01,  2.21428735e+00,
#            5.33695187e-01,  5.22183989e-01,  1.79224445e-01,
#           -3.28690619e-02,  4.03148488e-01,  3.25060240e-01,
#            3.05554826e-01, -7.67814604e-01,  9.90646475e-01,
#           -6.24893850e-01],
#          [ 4.16107796e-01,  5.26929454e-01,  4.20846372e-01,
#            2.08842944e-01, -1.48800128e-01, -9.08924149e-01,
#            2.14811245e+00,  3.98521571e-01,  8.72880283e-01,
#            9.80798035e-01,  9.83707604e-02,  1.65006481e+00,
#            1.47672749e+00, -8.82237295e-01,  8.72272693e-01,
#            6.49315436e-01],
#          [ 9.68668082e-01,  2.14859805e+00, -7.63995389e-01,
#           -1.11006584e+00, -8.08920006e-01,  1.93771682e+00,
#            1.16451497e+00,  2.76744169e-01,  5.18100401e-01,
#           -1.65362634e+00,  8.07272462e-01,  1.55078353e-01,
#            1.03960475e+00, -9.34652461e-01, -4.66343516e-01,
#            1.60940556e-01],
#          [ 3.47333978e-02,  1.15760295e+00,  1.17240684e-01,
#           -2.18685654e-01, -7.27863405e-01,  2.70383160e-01,
#            1.31852369e-01,  1.17884286e-02, -4.22567498e-01,
#            1.04464554e-01,  6.77510093e-01, -1.46284535e+00,
#           -1.56396099e+00,  7.19251557e-01, -2.89647013e-01,
#            1.06977627e+00]]),
#   'b': array([[ 0.77708427],
#          [ 1.87666714],
#          [-0.11434974],
#          [ 1.49851963],
#          [ 0.63617739],
#          [-0.37793353],
#          [ 0.52448162],
#          [ 0.86922896],
#          [ 1.94346048],
#          [-1.75829484],
#          [ 1.32024695],
#          [-0.26360779],
#          [-0.79643173],
#          [-1.17259857],
#          [-0.05758957],
#          [ 0.1159896 ]])},
#  {'W': array([[ 0.27341627,  1.14855439,  1.65368585,  0.44162542,  1.01917925,
#           -2.09517961, -3.67729878, -0.18222185,  0.08701935, -2.1007943 ,
#           -0.28931623,  1.19115656,  2.23651113, -0.62182362,  0.47428467,
#            1.02947145]]),
#   'b': array([[-0.4541792]])}]

# %%
Xc, yc = make_circles(n_samples=100, noise=0.1, factor=0.3, random_state=0)
Xc = Xc.T
yc = yc.reshape((1, yc.shape[0]))

print('dimensions de Xc:', Xc.shape)
print('dimensions de yc:', yc.shape)

plt.scatter(Xc[0, :], Xc[1, :], c=yc, cmap='summer')
plt.show()
# Out:
# dimensions de Xc: (2, 100)
# dimensions de yc: (1, 100)

# %%
params = neural_network(Xc, yc)
# Out:
# Final loss: 58.926184863984766
# Final accuracy: 0.76

# %%
params
# Out:
# [{'W': array([[ 0.12932839, -0.31588133],
#          [ 0.30081304,  1.04452042],
#          [ 2.37370572, -0.93913732],
#          [ 0.94536973, -1.31020886],
#          [-1.73736008,  0.5223341 ],
#          [ 1.10293958, -0.43726002],
#          [ 0.09309157, -0.92780291],
#          [-1.95309966,  0.69222116],
#          [-0.00919112,  1.67556549],
#          [-0.23544503],
#          [-0.5772695 ],
#          [ 1.48263061],
#          [-0.37148056],
#          [-0.2000994 ]])},
#  {'W': array([[-2.5685633 ,  0.71827886,  1.22418822, -0.1552812 ,  1.24170628,
#            1.29795472,  0.23074942,  1.65399712,  0.24592794,  0.22428086,
#            0.58063497, -0.15862965, -0.89108556, -2.00935347,  0.63728695,
#            0.59497319]]),
#   'b': array([[-0.73494274]])}]

# %%
params = neural_network(Xc, yc, hidden_layers=[16, 16])
# Out:
# Final loss: 58.05900966710423
# Final accuracy: 0.83

# %%
params
# Out:
# [{'W': array([[-0.07044945,  0.7636644 ],
#          [-2.63664461,  0.53234191],
#          [ 0.83979817, -0.15578686],
#          [ 0.56669896,  1.07043838],
#          [-1.92990308, -0.28961686],
#          [-1.82142996, -1.60332389],
#          [ 0.38238391,  2.51551781],
#          [ 0.97255606,  0.99931458],
#          [-0.67012074,  1.1503436 ],
#          [-0.41536081, -1.16163254],
#          [-0.02380313,  0.36699912],
#          [-1.59650826,  0.59935229],
#          [ 0.60604394,  0.90625628],
#          [-0.61577517, -0.11810405],
#          [-1.41745204,  0.16811926],
#          [-0.74219001, -0.96169847]]),
#   'b': array([[ 0.27605161],
#          [-0.65447549],
#          [-1.72157919],
#          [ 0.5636503 ],
#          [ 0.93668127],
#          [-0.06963191],
#          [ 1.77046833],
#          [ 0.15120026],
#          [-0.36017991],
#          [ 0.42380102],
#          [ 1.0107863 ],
#          [-2.91733012],
#          [-0.7955852 ],
#          [ 0.31175861],
#          [ 1.45760898],
#          [-0.10888757]])},
#  {'W': array([[-0.07122475,  0.85887107, -0.31897692,  0.26964172, -0.71239428,
#            0.65240525,  0.44945183,  3.04946349,  0.24336639,  1.00014894,
#            0.44729659,  1.14447492, -0.37980409,  0.40421199, -0.90084839,
#            0.39169184],
#          [-0.21987686,  0.7533926 , -2.54730597,  1.14559916,  0.46373213,
#           -1.81257706,  1.29015066,  1.84774625,  0.74223861,  1.51251868,
#            1.11553405, -1.62607215, -0.87249681, -1.49407259, -1.27408628,
#            0.33308626],
#          [ 0.83838954,  1.03588392,  2.76210487,  1.01725472, -1.24646971,
#            0.00422746, -1.29462952,  0.03382692,  0.41054551,  0.37534957,
#            1.13305973, -0.56849755, -0.06268227,  0.85137779, -1.12287368,
#           -0.81716524],
#          [ 0.46800382,  0.5859813 ,  0.88468687,  0.5942365 ,  0.57412402,
#           -1.00864679,  0.11749664, -0.79806631,  0.31241165,  1.11124896,
#            0.37547157,  2.33207637, -2.70190042, -0.1417036 , -0.44145277,
#            0.04777303],
#          [ 0.69912454, -2.25281103, -0.54510433, -1.75287983, -0.1248336 ,
#            0.70893852,  0.5347047 ,  0.88483352,  0.66306658, -0.28051958,
#           -1.38287436, -0.16088218,  1.06946162,  0.03652878, -0.32884934,
#            0.03282198],
#          [-1.82587678, -0.08407828, -0.79897096, -1.00942424, -0.23414312,
#            2.19762258, -1.67296401, -0.06068285, -0.68943605,  0.48742124,
#            1.25436251, -0.10707966,  0.60344721, -0.57469256,  0.39396847,
#            0.98242058],
#          [ 1.44184927, -0.21681788, -0.75841956,  0.76046382,  1.21862724,
#            0.06038091,  0.12464194, -1.20462554,  2.3831796 ,  0.04190634,
#           -1.7817962 ,  0.26124386,  0.48146963, -1.73577333, -0.47563534,
#            1.99199961],
#          [-0.27061334, -0.36997032,  0.77228041, -1.90894063, -1.59949202,
#            1.16537956,  0.83417328, -0.01871184,  2.27098112, -1.8267649 ,
#            2.24252249,  0.88248017,  0.0563409 , -0.27399491,  0.00618141,
#            0.68887357],
#          [-0.1380935 ,  0.57479407,  0.24764008, -0.44421953,  0.58128621,
#            0.16073723,  0.13696215,  0.11412289, -0.19096808,  0.7708139 ,
#           -0.96123088,  0.50664572, -1.26730005, -1.19956248, -1.49014387,
#           -0.86625189],
#          [ 0.69422361,  0.37348403, -0.00482526, -2.14004997, -0.5690417 ,
#            0.3559518 , -0.67823931,  2.0144236 , -0.268671  , -1.26991367,
#           -1.22478917, -0.68652059, -0.51127098,  0.80869785, -1.33371188,
#            0.51914946],
#          [ 1.13786994, -1.33778782,  1.19017942,  0.05118392,  0.24386729,
#            0.91097119, -0.04958399,  0.25679517, -0.63975087,  0.12182069,
#            1.47688278,  0.61609628,  0.23634426,  0.12695002,  1.81619777,
#            1.38994201],
#          [-0.62246554, -0.34036252,  1.61432681, -1.2030687 , -0.69509262,
#           -0.02708335, -0.0388398 , -1.59258683,  0.00976212, -0.14378582,
#            0.6962269 ,  0.73374243,  2.03789235, -0.42116756,  1.59319936,
#           -0.78233325],
#          [ 1.28747586,  1.12097301,  0.07738101,  0.34063855, -0.61591878,
#           -1.02332894, -1.34725123, -0.3404242 , -1.80342585,  0.09111517,
#           -0.45868826,  1.64638178, -1.52612953, -2.40140133,  0.58059291,
#           -0.5369437 ],
#          [ 1.37103331,  0.26242053,  0.69577141,  0.65686205, -0.36921025,
#           -0.05639177, -2.12658795, -0.78916573, -0.18095956, -0.24139136,
#            1.44422186,  0.80451221, -0.02041125,  0.53803647, -0.41059313,
#           -1.0526386 ],
#          [ 1.23969019, -0.39753125, -0.88081826,  1.53380723, -0.53138736,
#            1.87657969, -0.86880218,  1.09420687, -1.14405129,  1.16856025,
#            1.28065402,  0.34395177, -0.20580003, -1.14225836,  0.52960299,
#            2.56183665],
#          [-2.03945505, -0.58717219, -0.57793275, -1.6351852 , -0.57017886,
#            0.76089348, -0.24086297, -0.92990521,  0.65395293, -0.34775066,
#           -0.89067283, -1.22654746, -0.39197287,  0.93709083, -0.47170129,
#            1.0394574 ]]),
#   'b': array([[ 0.93932193],
#          [ 0.09099128],
#          [-0.71711294],
#          [-1.59151197],
#          [ 0.25721665],
#          [-1.27219275],
#          [ 1.24101164],
#          [ 2.75499104],
#          [ 0.83616491],
#          [-0.44691197],
#          [ 1.02565183],
#          [ 1.52877315],
#          [ 0.13692009],
#          [ 0.61426185],
#          [ 0.40146067],
#          [-0.97894093]])},
#  {'W': array([[ 2.23137069,  0.75545473, -1.65950316, -0.39737432, -0.65310765,
#           -1.49484647,  0.24948582, -0.67229293,  0.73154558,  0.6036886 ,
#            1.12862468, -0.65210931, -0.49381692, -2.95335803,  0.52534486,
#            1.23682798]]),
#   'b': array([[-0.95281879]])}]
